# %% [markdown]
#  ### 1. Archive Exploration
#
#
# -  What is this data about?
#
# A compilation of occurance records of arthopod prey of species in California drylands.
#
# - Is this data collected in-situ by the authors or is it a synthesis of multiple datasets?
#
#  Synthesis of multiple data sets
#
# - During what time frame were the observations in the dataset collected?
#
# 1945 - 2022
#
# - Does this dataset come with an associated metadata file?
#
# Yes
#
# - Does the dataset contain sensitive data?
#
# No
#
# citation:
#
#  Rachel King, Jenna Braun, Michael Westphal, & CJ Lortie. (2023). Compiled occurrence records for prey items of listed species found in California drylands with associated environmental data. Knowledge Network for Biocomplexity. doi:10.5063/F1VM49RH.
#
# date of access:
#
# 10/3/2025
#
# Link to the archive:
#
#  doi:10.5063/F1VM49RH

# %% [markdown]
# ### 2. Metadata exploration

# %%
import pandas as pd

# Import data
metadata = pd.read_csv('https://knb.ecoinformatics.org/knb/d1/mn/v2/object/urn%3Auuid%3A3baf7289-bf90-4db3-ad11-58785c09b26e')
metadata.head()
# Out:
#   attribute                            description
# 0     class   taxonomic class of observed organism
# 1     order   taxonomic order of observed organism
# 2    family  taxonomic family of observed organism
# 3     genus                             genus name
# 4   species               full latin binomial name

# %%
# Load data
# Load prey data from csv link
prey = pd.read_csv('https://knb.ecoinformatics.org/knb/d1/mn/v2/object/urn%3Auuid%3A23d42528-1048-45d4-85d1-7e13b666e744')

# Check type of prey object
print(type(prey), '\n')
print(prey.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
#
#           class        order           family          genus  \
# 0       Insecta      Odonata     Libellulidae      Sympetrum
# 1  Malacostraca      Isopoda  Armadillidiidae  Armadillidium
# 2       Insecta  Hymenoptera           Apidae         Bombus
# 3       Insecta  Hymenoptera           Apidae           Apis
# 4       Insecta    Hemiptera        Lygaeidae     Oncopeltus
#
#                  species        lat        long             eventDate   day  \
# 0    Sympetrum corruptum  37.173971 -121.856329  2020-09-29T08:24:00Z  29.0
# 1  Armadillidium vulgare  37.688580 -122.436608  2021-12-04T14:49:59Z   4.0
# 2    Bombus vosnesenskii  33.774911 -116.679713  2021-06-18T08:52:00Z  18.0
# 3         Apis mellifera  32.848001 -117.050126  2016-04-17T09:28:00Z  17.0
# 4   Oncopeltus fasciatus  32.739453 -117.133980  2019-04-06T18:44:31Z   6.0
#
#    month  ...         bio4        bio5       bio6        bio7        bio8  \
# ...

# %% [markdown]
# ### 4. Look at your data

# %%
prey
# use a pandas option to show all coloumns instead of minimizing
pd.set_option("display.max.columns", None)
prey

# This functions allows the display to show all columns available instead of shortening the list
# Out:
#                class        order           family          genus  \
# 0            Insecta      Odonata     Libellulidae      Sympetrum
# 1       Malacostraca      Isopoda  Armadillidiidae  Armadillidium
# 2            Insecta  Hymenoptera           Apidae         Bombus
# 3            Insecta  Hymenoptera           Apidae           Apis
# 4            Insecta    Hemiptera        Lygaeidae     Oncopeltus
# ...              ...          ...              ...            ...
# 111151       Insecta  Hymenoptera       Formicidae   Pogonomyrmex
# 111152       Insecta  Hymenoptera       Formicidae   Pogonomyrmex
# 111153       Insecta  Hymenoptera       Formicidae     Liometopum
# 111154       Insecta  Hymenoptera       Formicidae   Pogonomyrmex
# 111155       Insecta  Lepidoptera      Nymphalidae        Vanessa
#
#                           species        lat        long  \
# 0             Sympetrum corruptum  37.173971 -121.856329
# ...

# %% [markdown]
# ### 5. pd.DataFrame preliminary exploration

# %%
# head()
# returns the first five rows of the data frame
prey.head()
# Out:
#           class        order           family          genus  \
# 0       Insecta      Odonata     Libellulidae      Sympetrum
# 1  Malacostraca      Isopoda  Armadillidiidae  Armadillidium
# 2       Insecta  Hymenoptera           Apidae         Bombus
# 3       Insecta  Hymenoptera           Apidae           Apis
# 4       Insecta    Hemiptera        Lygaeidae     Oncopeltus
#
#                  species        lat        long             eventDate   day  \
# 0    Sympetrum corruptum  37.173971 -121.856329  2020-09-29T08:24:00Z  29.0
# 1  Armadillidium vulgare  37.688580 -122.436608  2021-12-04T14:49:59Z   4.0
# 2    Bombus vosnesenskii  33.774911 -116.679713  2021-06-18T08:52:00Z  18.0
# 3         Apis mellifera  32.848001 -117.050126  2016-04-17T09:28:00Z  17.0
# 4   Oncopeltus fasciatus  32.739453 -117.133980  2019-04-06T18:44:31Z   6.0
#
#    month  year institutionCode  coordinateUncertaintyInMeters  \
# 0    9.0  2020     iNaturalist                          684.0
# ...

# %%
# tail()
# Returns the last 5 rows of the data frame
prey.tail()
# Out:
#           class        order       family         genus  \
# 111151  Insecta  Hymenoptera   Formicidae  Pogonomyrmex
# 111152  Insecta  Hymenoptera   Formicidae  Pogonomyrmex
# 111153  Insecta  Hymenoptera   Formicidae    Liometopum
# 111154  Insecta  Hymenoptera   Formicidae  Pogonomyrmex
# 111155  Insecta  Lepidoptera  Nymphalidae       Vanessa
#
#                           species        lat        long  \
# 111151  Pogonomyrmex californicus  33.660853 -115.721380
# 111152  Pogonomyrmex californicus  35.933333 -116.716667
# 111153     Liometopum occidentale  34.156833 -118.726833
# 111154  Pogonomyrmex californicus  32.989167 -116.658500
# 111155             Vanessa cardui  36.251400 -117.731400
#
#                    eventDate   day  month  year institutionCode  \
# 111151  1980-04-10T00:00:00Z  10.0    4.0  1980             MCZ
# 111152  1998-03-26T00:00:00Z  26.0    3.0  1998             MCZ
# 111153  2010-05-21T00:00:00Z  21.0    5.0  2010             MCZ
# ...

# %%
#info()
prey.info()
# returns Data type, Non-Null counts, Column names and total observations
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111156 entries, 0 to 111155
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   class                          111156 non-null  object
#  1   order                          111054 non-null  object
#  2   family                         111156 non-null  object
#  3   genus                          111156 non-null  object
#  4   species                        111156 non-null  object
#  5   lat                            111156 non-null  float64
#  6   long                           111156 non-null  float64
#  7   eventDate                      111156 non-null  object
#  8   day                            110998 non-null  float64
#  9   month                          111127 non-null  float64
#  10  year                           111156 non-null  int64
#  11  institutionCode                110414 non-null  object
# ...

# %%
# nunique()
prey.nunique()

# Displays number of unique entries in each column
# Out:
# class                                 4
# order                                18
# family                               63
# genus                                92
# species                              97
# lat                               91909
# long                              91965
# eventDate                        102140
# day                                  31
# month                                12
# year                                 77
# institutionCode                      77
# coordinateUncertaintyInMeters      4450
# basisOfRecord                         4
# individualCount                      42
# datasetKey                           88
# ID                               111156
# bio1                              11778
# bio10                             11981
# bio11                             11803
# bio12                             12117
# bio13                             12020
# bio14                              4586
# ...

# %%
# shape
prey.shape
# Displays size of data frame how many columns by how many rows
# Out:
# (111156, 40)

# %%
# columns
prey.columns
# Displays column names
# Out:
# Index(['class', 'order', 'family', 'genus', 'species', 'lat', 'long',
#        'eventDate', 'day', 'month', 'year', 'institution_code',
#        'coordinateUncertaintyInMeters', 'basisOfRecord', 'individualCount',
#        'dataset_key', 'ID', 'bio1', 'bio10', 'bio11', 'bio12', 'bio13',
#        'bio14', 'bio15', 'bio16', 'bio17', 'bio18', 'bio19', 'bio2', 'bio3',
#        'bio4', 'bio5', 'bio6', 'bio7', 'bio8', 'bio9', 'dist', 'dem90_hf',
#        'lc_class', 'ndvi'],
#       dtype='object')

# %%
# dtypes
prey.dtypes
# Displays the types of data
# Out:
# class                             object
# order                             object
# family                            object
# genus                             object
# species                           object
# lat                              float64
# long                             float64
# eventDate                         object
# day                              float64
# month                            float64
# year                               int64
# institutionCode                   object
# coordinateUncertaintyInMeters    float64
# basisOfRecord                     object
# individualCount                  float64
# datasetKey                        object
# ID                                 int64
# bio1                             float64
# bio10                            float64
# bio11                            float64
# bio12                            float64
# bio13                            float64
# bio14                            float64
# ...

# %%
### 6. Update column names

# %%
#Change the column names of institutionCode and datasetKey to institution_code and dataset_key, 

prey = prey.rename(columns = {'institutionCode' : 'institution_code', 'datasetKey' : 'dataset_key'})

#respectively. Make sure you’re actually updating the dataframe. 

# prey = 

#HINT: look for the documentation on the rename method for pandas.DataFrames.
# ?prey.rename
# Out:
# Signature:
# prey.rename(
#     mapper: 'Renamer | None' = None,
#     *,
#     index: 'Renamer | None' = None,
#     columns: 'Renamer | None' = None,
#     axis: 'Axis | None' = None,
#     copy: 'bool | None' = None,
#     inplace: 'bool' = False,
#     level: 'Level | None' = None,
#     errors: 'IgnoreRaise' = 'ignore',
# ) -> 'DataFrame | None'
# Docstring:
# Rename columns or index labels.
#
# Function / dict values must be unique (1-to-1). Labels not contained in
# a dict / Series will be left as-is. Extra labels listed don't throw an
# error.
#
# See the :ref:`user guide <basics.rename>` for more.
#
# Parameters
# ----------
# mapper : dict-like or function
#     Dict-like or function transformations to apply to
#     that axis' values. Use either ``mapper`` and ``axis`` to
#     specify the axis to target with ``mapper``, or ``index`` and
#     ``columns``.
# index : dict-like or function
#     Alternative to specifying axis (``mapper, axis=0``
# ...

# %% [markdown]
# ### 7. Subsetting

# %%
# Select only the preservered specimes from prey.

specimens = prey[prey["basisOfRecord"] =='PRESERVED_SPECIMEN']
print(specimens.shape)
# Select observations between 1992 and 2000

old_obs = prey[prey['year'].between(1992,2000)]

old_obs = prey[(prey['year'] >= 1992) & (prey['year'] <= 2000)]

# Select all rows for columns species and eventDate.

prey_rows = prey[['species', 'eventDate']]
prey_rows.shape
# Select observations that are greater than 37° latitude and less than 39° latitude

prey[(prey['lat']>37) & (prey['lat']<39)]
# Out:
# (10482, 40)
#                class        order           family          genus  \
# 0            Insecta      Odonata     Libellulidae      Sympetrum
# 1       Malacostraca      Isopoda  Armadillidiidae  Armadillidium
# 5            Insecta      Diptera        Syrphidae     Allograpta
# 9            Insecta  Lepidoptera      Nymphalidae        Vanessa
# 10           Insecta  Lepidoptera       Sphingidae          Hyles
# ...              ...          ...              ...            ...
# 111125       Insecta  Hymenoptera           Apidae         Bombus
# 111128  Malacostraca      Isopoda        Oniscidae        Oniscus
# 111138       Insecta      Diptera        Syrphidae      Toxomerus
# 111140       Insecta  Hymenoptera           Apidae           Apis
# 111145       Insecta   Coleoptera    Coccinellidae     Hippodamia
#
#                       species        lat        long             eventDate  \
# 0         Sympetrum corruptum  37.173971 -121.856329  2020-09-29T08:24:00Z
# ...
