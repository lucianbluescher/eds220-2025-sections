# %% [markdown]
# # World Database on Protected Areas (WDPA) - Central America Analysis
#
# This notebook contains preliminary analysis of **protected area coverage in Central American countries** using the World Database on Protected Areas (WDPA) datasets.
#
# The data accessed here is a subset of the original dataset and it *only includes polygons for  protected areas in Latin America* (the original dataset is global with both polygon and point data). This subset was prepared for educational purposes and can be downloaded from the course's [Google Drive](https://drive.google.com/drive/folders/1USqhiMLyN8GE05B8WJmHabviJGnmAsLP?usp=share_link) through the zip file `WDPA_Nov2025_Latam.zip`. It maintains the file structure of the original complete dataset.
#
# ## References
# UNEP-WCMC and IUCN (2025), Protected Planet:
# The World Database on Protected Areas (WDPA) [On-line], November 2025,
# Cambridge, UK: UNEP-WCMC and IUCN. Available at: [www.protectedplanet.net.](http://www.protectedplanet.net)
#
# UNEP-WCMC (2019). User Manual for the World Database on Protected Areas and world database on other
# effective area-based conservation measures: 1.6. UNEP-WCMC: Cambridge, UK. Available at:
# [http://wcmc.io/WDPA_Manual](http://wcmc.io/WDPA_Manual)

# %% [markdown]
# ## Data import and preparation

# %%
import os
import pandas as pd
import geopandas as gpd

pd.set_option('display.max_columns', None)

# ------ IMPORT DATASETS ------

data_folder = os.path.join('data', 'WDPA_Nov2025_Latam')

fp = os.path.join(data_folder, 'WDPA_Nov2025_Latam_shp_0', 'WDPA_Nov2025_Latam_shp0-polygons.shp')
wdpa0 = gpd.read_file(fp)

fp = os.path.join(data_folder, 'WDPA_Nov2025_Latam_shp_1', 'WDPA_Nov2025_Latam_shp1-polygons.shp')
wdpa1 = gpd.read_file(fp)

fp = os.path.join(data_folder, 'WDPA_Nov2025_Latam_shp_2', 'WDPA_Nov2025_Latam_shp2-polygons.shp')
wdpa2 = gpd.read_file(fp)

# Standardize column names to lowercase
wdpa0.columns = wdpa0.columns.str.lower()
wdpa1.columns = wdpa1.columns.str.lower()

wdpa2.columns = wdpa2.columns.str.lower()

# %%
print("WDPA0 shape:", wdpa0.shape)
wdpa0.head()
# Out:
# WDPA0 shape: (3679, 31)
#    wdpaid wdpa_pid pa_def                                  name  \
# 0     1.0        1      1  Diamond Reef and Salt Fish Tail Reef
# 1     2.0        2      1                         Palaster Reef
# 2     3.0        3      1                Laguna de los Pozuelos
# 3     4.0        4      1                               Formosa
# 4     6.0        6      1                         Los Glaciares
#
#                 orig_name              desig        desig_eng desig_type  \
# 0            Diamond Reef     Marine Reserve   Marine Reserve   National
# 1           Palaster Reef     Marine Reserve   Marine Reserve   National
# 2  Laguna de los Pozuelos  Monumento Natural  Nature Monument   National
# 3                 Formosa    Reserva Natural   Nature Reserve   National
# 4           Los Glaciares    Parque Nacional    National Park   National
#
#   iucn_cat        int_crit marine  rep_m_area  gis_m_area     rep_area  \
# 0       Ia  Not Applicable      2   14.572487   14.587808    14.581467
# 1       Ia  Not Applicable      2    3.829107    3.833094     3.831674
# 2      III  Not Applicable      0    0.000000    0.000000   160.000000
# 3       Ia  Not Applicable      0    0.000000    0.000000    90.050000
# 4       II  Not Applicable      0    0.000000    0.000000  5385.500000
#
#       gis_area         no_take  no_tk_area      status  status_yr  \
# 0    14.587808             All   14.572487  Designated       1973
# 1     3.833094             All    3.829107  Designated       1973
# 2   217.931016  Not Applicable    0.000000  Designated       1980
# 3    90.746053  Not Applicable    0.000000  Designated       1968
# 4  5368.384077  Not Applicable    0.000000  Designated       1937
#
#                                  gov_type      own_type  \
# 0  Federal or national ministry or agency         State
# 1  Federal or national ministry or agency         State
# 2  Federal or national ministry or agency  Not Reported
# 3  Federal or national ministry or agency  Not Reported
# 4  Federal or national ministry or agency  Not Reported
#
#                               mang_auth  \
# 0                    Fisheries Division
# 1                    Fisheries Division
# 2  Administración de Parques Nacionales
# 3  Administración de Parques Nacionales
# 4  Administración de Parques Nacionales
#
#                                            mang_plan           verif  \
# 0                                       Not Reported  State Verified
# 1                                       Not Reported  State Verified
# 2                                       Not Reported  State Verified
# 3  https://sib.gob.ar/archivos/plan_de_gestion_RN...  State Verified
# 4  https://sib.gob.ar/archivos/PG_PN_LOS_GLACIARE...  State Verified
#
#    metadataid sub_loc parent_iso iso3       supp_info        cons_obj  \
# 0        1807   AG-04        ATG  ATG  Not Applicable  Not Applicable
# 1        1807   AG-10        ATG  ATG  Not Applicable  Not Applicable
# 2        1935    AR-Y        ARG  ARG  Not Applicable  Not Applicable
# 3        1935    AR-P        ARG  ARG  Not Applicable  Not Applicable
# 4        1935    AR-Z        ARG  ARG  Not Applicable  Not Applicable
#
#                                             geometry
# 0  POLYGON ((-61.82494 17.18497, -61.82497 17.184...
# 1  POLYGON ((-61.74007 17.52001, -61.77174 17.526...
# 2  POLYGON ((-65.98955 -22.47423, -65.99441 -22.4...
# 3  POLYGON ((-61.83791 -24.20686, -61.83781 -24.2...
# 4  POLYGON ((-73.14850 -49.27008, -73.14368 -49.2...

# %%
print("WDPA1 shape:", wdpa1.shape)
wdpa1.head()
# Out:
# WDPA1 shape: (3421, 31)
#      wdpaid wdpa_pid pa_def                         name  \
# 0  478006.0   478006      1         Estero La Manzanilla
# 1  478007.0   478007      1      Laguna Barra de Navidad
# 2  478008.0   478008      1              Estero Majahuas
# 3  478009.0   478009      1          Laguna Chalacatepec
# 4  478010.0   478010      1  Oasis de la Sierra El Pilar
#
#                      orig_name  \
# 0         Estero La Manzanilla
# 1      Laguna Barra de Navidad
# 2              Estero Majahuas
# 3          Laguna Chalacatepec
# 4  Oasis de la Sierra El Pilar
#
#                                                desig  \
# 0  Sitio Ramsar, Humedal de Importancia Internaci...
# 1  Sitio Ramsar, Humedal de Importancia Internaci...
# 2  Sitio Ramsar, Humedal de Importancia Internaci...
# 3  Sitio Ramsar, Humedal de Importancia Internaci...
# 4  Sitio Ramsar, Humedal de Importancia Internaci...
#
#                                           desig_eng     desig_type  \
# 0  Ramsar Site, Wetland of International Importance  International
# 1  Ramsar Site, Wetland of International Importance  International
# 2  Ramsar Site, Wetland of International Importance  International
# 3  Ramsar Site, Wetland of International Importance  International
# 4  Ramsar Site, Wetland of International Importance  International
#
#        iucn_cat                int_crit marine  rep_m_area  gis_m_area  \
# 0  Not Reported     (ii)(iv)(vii)(viii)      0         0.0    0.000334
# 1  Not Reported  (i)(ii)(iv)(vii)(viii)      1         0.0    2.817812
# 2  Not Reported     (ii)(iv)(vii)(viii)      0         0.0    0.004628
# 3  Not Reported  (i)(ii)(iv)(vii)(viii)      0         0.0    0.000000
# 4  Not Reported            (i)(ii)(iii)      0         0.0    0.000000
#
#    rep_area     gis_area         no_take  no_tk_area      status  status_yr  \
# 0      2.64     2.641565  Not Applicable         0.0  Designated       2008
# 1      7.94     7.946036    Not Reported         0.0  Designated       2008
# 2      7.86     7.867309  Not Applicable         0.0  Designated       2008
# 3     10.93    10.942113  Not Applicable         0.0  Designated       2008
# 4   1808.03  1775.209223  Not Applicable         0.0  Designated       2008
#
#        gov_type      own_type     mang_auth     mang_plan           verif  \
# 0  Not Reported  Not Reported  Not Reported  Not Reported  State Verified
# 1  Not Reported  Not Reported  Not Reported  Not Reported  State Verified
# 2  Not Reported  Not Reported  Not Reported  Not Reported  State Verified
# 3  Not Reported  Not Reported  Not Reported  Not Reported  State Verified
# 4  Not Reported  Not Reported  Not Reported  Not Reported  State Verified
#
#    metadataid sub_loc parent_iso iso3       supp_info        cons_obj  \
# 0        1856  MX-JAL        MEX  MEX  Not Applicable  Not Applicable
# 1        1856  MX-JAL        MEX  MEX  Not Applicable  Not Applicable
# 2        1856  MX-JAL        MEX  MEX  Not Applicable  Not Applicable
# 3        1856  MX-JAL        MEX  MEX  Not Applicable  Not Applicable
# 4        1856  MX-BCS        MEX  MEX  Not Applicable  Not Applicable
#
#                                             geometry
# 0  POLYGON ((-104.82210 19.31424, -104.82200 19.3...
# 1  POLYGON ((-104.68078 19.20175, -104.68132 19.2...
# 2  POLYGON ((-105.37759 19.84940, -105.37710 19.8...
# 3  POLYGON ((-105.21927 19.64621, -105.21986 19.6...
# 4  POLYGON ((-110.90110 25.02583, -110.88632 25.0...

# %%
print("WDPA2 shape:", wdpa2.shape)
wdpa2.head()
# Out:
# WDPA2 shape: (1363, 31)
#         wdpaid   wdpa_pid pa_def  \
# 0  555636487.0  555636487      1
# 1  555636488.0  555636488      1
# 2  555636489.0  555636489      1
# 3  555636490.0  555636490      1
# 4  555636491.0  555636491      1
#
#                                                 name  \
# 0             Reserva Biológica Do Parque Equitativa
# 1  Parque Natural Municipal Corredores De Biodive...
# 2      Parque Natural Municipal De Brigadeiro Tobias
# 3    Reserva Particular Do Patrimônio Natural Boa Fé
# 4                     Parque Estadual Ponta Da Tulha
#
#                                            orig_name  \
# 0             Reserva Biológica Do Parque Equitativa
# 1  Parque Natural Municipal Corredores De Biodive...
# 2      Parque Natural Municipal De Brigadeiro Tobias
# 3    Reserva Particular Do Patrimônio Natural Boa Fé
# 4                     Parque Estadual Ponta Da Tulha
#
#                                       desig                         desig_eng  \
# 0                         Reserva Biológica                Biological Reserve
# 1                                    Parque                              Park
# 2                                    Parque                              Park
# 3  Reserva Particular do Patrimônio Natural  Natural Heritage Private Reserve
# 4                                    Parque                              Park
#
#   desig_type iucn_cat        int_crit marine  rep_m_area  gis_m_area  \
# 0   National       Ia  Not Applicable      0         0.0         0.0
# 1   National       II  Not Applicable      0         0.0         0.0
# 2   National       II  Not Applicable      0         0.0         0.0
# 3   National       IV  Not Applicable      0         0.0         0.0
# 4   National       II  Not Applicable      0         0.0         0.0
#
#     rep_area   gis_area         no_take  no_tk_area      status  status_yr  \
# 0   1.570550   1.570551  Not Applicable         0.0  Designated       2014
# 1   0.715180   0.715174  Not Applicable         0.0  Designated       2011
# 2   0.118531   0.118531  Not Applicable         0.0  Designated       2015
# 3   0.141830   0.141829  Not Applicable         0.0  Designated       2016
# 4  17.053069  17.052181  Not Applicable         0.0  Designated       2015
#
#                           gov_type               own_type  \
# 0  Sub-national ministry or agency           Not Reported
# 1  Sub-national ministry or agency           Not Reported
# 2  Sub-national ministry or agency           Not Reported
# 3            Individual landowners  Individual landowners
# 4  Sub-national ministry or agency           Not Reported
#
#                                            mang_auth     mang_plan  \
# 0  Secretaria Municipal De Meio Ambiente, Agricul...  Not Reported
# 1  Secretaria Do Meio Ambiente, Parques E Jardins...  Not Reported
# 2  Secretaria Do Meio Ambiente, Parques E Jardins...  Not Reported
# 3  Instituto Estadual De Meio Ambiente E Recursos...  Not Reported
# 4  Instituto Do Meio Ambiente E Recursos Hídricos...  Not Reported
#
#             verif  metadataid sub_loc parent_iso iso3       supp_info  \
# 0  State Verified        1802  BRA-RJ        BRA  BRA  Not Applicable
# 1  State Verified        1802  BRA-SP        BRA  BRA  Not Applicable
# 2  State Verified        1802  BRA-SP        BRA  BRA  Not Applicable
# 3  State Verified        1802  BRA-ES        BRA  BRA  Not Applicable
# 4  State Verified        1802  BRA-BA        BRA  BRA  Not Applicable
#
#          cons_obj                                           geometry
# 0  Not Applicable  MULTIPOLYGON (((-43.25874 -22.63150, -43.25894...
# 1  Not Applicable  POLYGON ((-47.47996 -23.39006, -47.48335 -23.3...
# 2  Not Applicable  POLYGON ((-47.36366 -23.50666, -47.36462 -23.5...
# 3  Not Applicable  POLYGON ((-41.14679 -20.07258, -41.14852 -20.0...
# 4  Not Applicable  POLYGON ((-39.06462 -14.59730, -39.06520 -14.5...

# %% [markdown]
# ## Calculate protected area coverage in Central America

# %%
# Calculate total protected reported area for each Central American country from WDPA datasets

# Standardize column names to lowercase
wdpa0.columns = wdpa0.columns.str.lower()
wdpa1.columns = wdpa1.columns.str.lower()
wdpa2.columns = wdpa2.columns.str.lower()

# Belize
area0 = wdpa0.loc[wdpa0["iso3"] == "BLZ", "rep_area"].sum()
area1 = wdpa1.loc[wdpa1["iso3"] == "BLZ", "rep_area"].sum()
area2 = wdpa2.loc[wdpa2["iso3"] == "BLZ", "rep_area"].sum()
total_area_blz = area0 + area1 + area2
print(f"Total protected area in Belize (sq. km): {total_area_blz:,.2f}")

# Costa Rica
area0 = wdpa0.loc[wdpa0["iso3"] == "CRI", "rep_area"].sum()
area1 = wdpa1.loc[wdpa1["iso3"] == "CRI", "rep_area"].sum()
area2 = wdpa2.loc[wdpa2["iso3"] == "CRI", "rep_area"].sum()
total_area_cri = area0 + area1 + area2
print(f"Total protected area in Costa Rica (sq. km): {total_area_cri:,.2f}")

# El Salvador
area0 = wdpa0.loc[wdpa0["iso3"] == "SLV", "rep_area"].sum()
area1 = wdpa1.loc[wdpa1["iso3"] == "SLV", "rep_area"].sum()
area2 = wdpa2.loc[wdpa2["iso3"] == "SLV", "rep_area"].sum()
total_area_slv = area0 + area1 + area2
print(f"Total protected area in El Salvador (sq. km): {total_area_slv:,.2f}")

# Guatemala
area0 = wdpa0.loc[wdpa0["iso3"] == "GTM", "rep_area"].sum()
area1 = wdpa1.loc[wdpa1["iso3"] == "GTM", "rep_area"].sum()
area2 = wdpa2.loc[wdpa2["iso3"] == "GTM", "rep_area"].sum()
total_area_gtm = area0 + area1 + area2
print(f"Total protected area in Guatemala (sq. km): {total_area_gtm:,.2f}")

# Honduras
area0 = wdpa0.loc[wdpa0["iso3"] == "HND", "rep_area"].sum()
area1 = wdpa1.loc[wdpa1["iso3"] == "HND", "rep_area"].sum()
area2 = wdpa2.loc[wdpa2["iso3"] == "HND", "rep_area"].sum()
total_area_hnd = area0 + area1 + area2
print(f"Total protected area in Honduras (sq. km): {total_area_hnd:,.2f}")

# Nicaragua
area0 = wdpa0.loc[wdpa0["iso3"] == "NIC", "rep_area"].sum()
area1 = wdpa1.loc[wdpa1["iso3"] == "NIC", "rep_area"].sum()
area2 = wdpa2.loc[wdpa2["iso3"] == "NIC", "rep_area"].sum()
total_area_nic = area0 + area1 + area2
print(f"Total protected area in Nicaragua (sq. km): {total_area_nic:,.2f}")

# Panama
area0 = wdpa0.loc[wdpa0["iso3"] == "PAN", "rep_area"].sum()
area1 = wdpa1.loc[wdpa1["iso3"] == "PAN", "rep_area"].sum()
area2 = wdpa2.loc[wdpa2["iso3"] == "PAN", "rep_area"].sum()
total_area_pan = area0 + area1 + area2
print(f"Total protected area in Panama (sq. km): {total_area_pan:,.2f}")
# Out:
# Total protected area in Belize (sq. km): 10,181.87
# Total protected area in Costa Rica (sq. km): 88,928.27
# Total protected area in El Salvador (sq. km): 5,701.12
# Total protected area in Guatemala (sq. km): 40,316.17
# Total protected area in Honduras (sq. km): 96,103.89
# Total protected area in Nicaragua (sq. km): 84,985.39
# Total protected area in Panama (sq. km): 42,906.28

# %%
# ----------------------------------------------------------------
# Calculate percentage of protected   area for Belize
pct_blz = (total_area_blz / 22966) * 100
print(f"Percentage of protected area in Belize relative to country's land area: {pct_blz:.2f}%\n")
# Out:
# Percentage of protected area in Belize relative to country's land area: 44.33%

# %%
# Plan refactoring 
def calculate_percentage_protected(total_area, country_area, country_name):
    # Standardize column names to lowercase
wdpa0.columns = wdpa0.columns.str.lower()
wdpa1.columns = wdpa1.columns.str.lower()
wdpa2.columns = wdpa2.columns.str.lower()

   # Panama
area0 = wdpa0.loc[wdpa0["iso3"] == "PAN", "rep_area"].sum()
area1 = wdpa1.loc[wdpa1["iso3"] == "PAN", "rep_area"].sum()
area2 = wdpa2.loc[wdpa2["iso3"] == "PAN", "rep_area"].sum()
total_area_pan = area0 + area1 + area2
print(f"Total protected area in Panama (sq. km): {total_area_pan:,.2f}")

# %%
country = ['BLZ', 'CRI', 'SLC', 'GTM', 'HND', 'NIC', 'PAN']

def area (wdpa0, wdpa1, wdpa2):
    x = pd.concat([wdpa0, wdpa1, wdpa2])
    x.columns = x.columns.str.lower()
    values = x["iso3"]
    for i in country:
        area = x.loc[x["iso3"] == i, "rep_area"].sum()
        print(f"Total protected area in {i} (sq. km): {area:,.2f}")

# %%
area(wdpa0, wdpa1, wdpa2)
# Out:
# Total protected area in BLZ (sq. km): 10,181.87
# Total protected area in CRI (sq. km): 88,928.27
# Total protected area in SLC (sq. km): 0.00
# Total protected area in GTM (sq. km): 40,316.17
# Total protected area in HND (sq. km): 96,103.89
# Total protected area in NIC (sq. km): 84,985.39
# Total protected area in PAN (sq. km): 42,906.28

# %%
countries = {'BLZ': 22966,
                 'CRI': 51180,
                 'SLV': 21041,
                 'GTM': 108889,
                 'HND': 112492,
                 'NIC': 130373,
                 'PAN': 75417}


for iso, name in countries.items():
    total_area = totals.loc[totals["iso3"] == iso, "rep_area"].value[0]
    pct = (total_area / land_area[iso]) * 100
    print(f"{name}: {pct:.2f}%")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[75], line 11
#       1 countries = {'BLZ': 22966,
#       2                  'CRI': 51180,
#       3                  'SLV': 21041,
#    (...)
#       6                  'NIC': 130373,
#       7                  'PAN': 75417}
#      10 for iso, name in countries.items():
# ---> 11     total_area = totals.loc[totals["iso3"] == iso, "rep_area"].value[0]
#      12     pct = (total_area / land_area[iso]) * 100
#      13     print(f"{name}: {pct:.2f}%")
#
# NameError: name 'totals' is not defined

# %%
# Combine gdfs


def calculate_percentage_protected(total_area, country_name, wdpa0, wdpa1, wdpa2):
    
        wdpa_combined = pd.concat([wdpa0, wdpa1, wdpa2])

        wdpa_combined.columns = wdpa_combined.columns.str.lower()

        total_predicted_area = wdpa_combined.loc[wdpa_combined["iso3"] == country_name, "rep_area"].sum()

        print(f"Total protected area in {country_name} (sq. km): {total_area:,.2f}")

        pct_protected = (total_area / total_predicted_area) * 100

        print(f"Percentage of protected area in {country_name} relative to countrys land area: {pct_protected: .2f}%\n")

countries = {'BLZ': 22966,
                 'CRI': 51180,
                 'SLV': 21041,
                 'GTM': 108889,
                 'HND': 112492,
                 'NIC': 130373,
                 'PAN': 75417}
    
for country, size in countries.items():
    calculate_percentage_protected(size, country, wdpa0, wdpa1, wdpa2)
# Out:
# Total protected area in BLZ (sq. km): 22,966.00
# Percentage of protected area in BLZ relative to countrys land area:  225.56%
#
# Total protected area in CRI (sq. km): 51,180.00
# Percentage of protected area in CRI relative to countrys land area:  57.55%
#
# Total protected area in SLV (sq. km): 21,041.00
# Percentage of protected area in SLV relative to countrys land area:  369.07%
#
# Total protected area in GTM (sq. km): 108,889.00
# Percentage of protected area in GTM relative to countrys land area:  270.09%
#
# Total protected area in HND (sq. km): 112,492.00
# Percentage of protected area in HND relative to countrys land area:  117.05%
#
# Total protected area in NIC (sq. km): 130,373.00
# Percentage of protected area in NIC relative to countrys land area:  153.41%
#
# Total protected area in PAN (sq. km): 75,417.00
# Percentage of protected area in PAN relative to countrys land area:  175.77%

# %% [markdown]
# **TO DO: Repeat percentage calculation for the rest of the Central American countries.**
#
# The   areas are:
# - Belize: 22,966 km²
# - Costa Rica: 51,180 km²
# - El Salvador: 21,041 km²
# - Guatemala: 108,889 km²
# - Honduras: 112,492 km²
# - Nicaragua: 130,375 km²
# - Panama: 75,417 km²
#
# Source: Wikipedia, November 5, 2025.

# %% [markdown]
# 5. Investigate issues
# Discuss the following with your team:
#
# Do these percentages make sense? Why or why not?
#
# No they seem too large.
#
# Are there known data quality or use recommendations this colleague should have taken into account since the start of the analysis? Take some time to look through the WDPA_WDOECM_Manual file.
#
#
# How should the analysis change if we wanted to calculate the percentage of terrestrial protected area per country accurately?
#
# We would have to filter to just terrestrial protected area in the concatination
